# %%
print("This is my second Python session. \n- learning Data Types in Python as on 22/09/2022")

""" Print Functions """

print(type(1))
print(type("Rahul"))
print(type(1.0))
print(type(False))
type(1)
type("Rahul")

print(7+8)        # Add numbers
print("Rahul" + " Grover")    # Add string 
print("Rahul" * 3)    # Multiple string 
print(12, 24, "Rahul", False)   #Using , seperate multiple values to be printed & printed in the same line. 
print("$", 25+3)    # Adding string to an operation. 


""" Variables """

# We can assign a particular value to a particulat name or an alias. (for labelling)
# Storing Value and givinng a meaningful name. 
# Most helpul with functions and Input

"""
Example:

balance = 2
balance = balance + 5

"""

x = 3
y = 8
print(x+y)
print(type(x+y))
      
""" NAMING CONVENTION """

"""
Variable name should strat with an alphabet or "_"
Should not start with number or special character 
Alpha Numeric 
"""

x = 3
y = "hello"
y = 'hello'
num = y
y = 5
num = 5
print(num, y)


print("2" + '2')    # String Concatenation


""" Input Function """

# Multiplying string with number using input function
name = input("What is your name? ")
number = int(input("What is your fav number? "))
print(name * number)

# Adding 2 numbers using input function
a = 5
b = 67
print("Total of a and b:", a+b)

# Multiplying 2 numbers using input function
name = int(input("No 1: "))
number = int(input("No 2: "))
print(name -  number)

# %% [markdown]
# # Data Types
#
#
# **Int**
#   - In Python, the int data type can represent all integers, positive or negative.
#
#         ..., -2, -1, 0, 1, 2, ... are all ints in Python.
#
#
#
# **Float**
#   - In Python, the float data type represents floating point numbers, positive or negative.
#
#         2.1, .2, 7., -90.234, 0.222321, 3.14 are all floats in Python.
#
#   - Even numbers like 2.0 that are whole numbers are considered floats because of the presence of the decimal point (the period).
#
#
#
# **String**
#   - The str data type represents a sequence of characters.
#
#   - In Python, they start and end with
#
#         " (double quote)
#         ' (single quote)
#         """ (triple double quotes)
#         ''' (triple single quotes)
#
#   - The following are examples of valid Python strings,
#
#         "hello", "2.0", 'str', """False""", '''true''
#
#
# **Bool**
#   - In Python, the bool data type represents one of two values:
#
#           True
#           False
#
#
# **Variable**
#   - A variable can be thought of as a container that stores a value.
#
#   - As a programmer, you can create your own variables that store different data types.
#
#   - The following is an example of a variable,
#
#
#       hello_world = "this variable holds a string"
#
#
#   - In python, variable names must:
#
#         -  not start with a number
#         -  not contain any special characters other than underscores (_).
#         -  not contain any spaces.
#
#
# **Input**
#
#   - The input function is built directly into Python as a means to gather user input from the command line.
#
#   - An important note is that it will always return a str object which will need to be converted to an int (for example) if you expect the user input to be an integer.
#
#
#         user_name = input()
#         print("Hello", user_name + "!")

# %%
c = int(input())
s = int(input())
p = s-c
print(p)
# Out:
# 20
# 25
# 5
