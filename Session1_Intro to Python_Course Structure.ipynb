# %%
print("This is my first Basic Python session with Scaler as on 20/09/2022")
print("\n")
print(f"Multiplication 5*3:", 5*3)
print(f"Floor Division 15//5:", 15//5)
print(f"Subtraction 5-3:", 5-3)
print(f"Division 15/5:", /0)
print(f"Modulo(Remainder) 2%15:", 2%15)
print(f"Exponentiation 5**2:", 5**2)
print(3.212 + 4.555)
# Out:
# This is my first Basic Python session with Scaler as on 20/09/2022
#
#
# Multiplication 5*3: 15
# Floor Division 15//5: 3
# Subtraction 5-3: 2
# Division 15/5: 0.0
# Modulo(Remainder) 2%15: 2
# Exponentiation 5**2: 25
# 7.7669999999999995

# %% [markdown]
# # Course Structure
#
# 1.   Intro to Python (session 1)
# 2.   Data Types (session 2)
#
#           A. Numeric
#           B. String
#           C. Boolean
#
# 3.   Operators (session 3)
#
#           A. +	Addition
#           B. -	Subtraction
#           C. *	Multiplication
#           D. /	Division
#           E. %	Modulo
#           F. **	Exponentiation (Division)
#           G. //	Floor division
#
# 4.   Control Statements (session 4)
#
#         *A. Conditional statements*
#           1. if statement
#           2. if-else
#           3. if-elif-else
#           4. nested if-else
#
#         *B. Iterative statements*
#           1. for loop
#           2. while loop
#
#         *C. Transfer statements*
#           1. break statement
#           2. continue statement
#           3. pass statements
#
# 5.   Basic Maths
# 6.   Looping Statements - (4 Sessions)
# 7.   Pattern Printing
# 8.   Functions - (2 Sessions)
# 9.   Lists - (5 Sessions)
# 10.  Lists and Tuples
# 11.  Dictionary
